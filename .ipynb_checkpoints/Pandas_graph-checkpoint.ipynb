# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import matplotlib.lines as mlines
import random

lines = np.load("04-03-2020_17-21-27.npy", allow_pickle=True)
print lines

fig, ax = plt.subplots()
plt.xlim(-20,20)
plt.ylim(-20,20)
ax.set_aspect(1)
for c in  lines[0]:
    circle1 = plt.Circle((c[0], c[1]), c[2], color='g')
    ax.add_artist(circle1)
# Out:
# [list([array([  4.2 ,   3.4 , -12.12]), array([ 4.2   , -1.6   , -1.9772])])
#  list([array([-1.    , -1.6   ,  0.4931]), array([-1.    , -6.6   , 10.6359]), array([-5.2   , -5.    , 12.6131])])]

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import matplotlib.lines as mlines

def newline(p1, p2):
    ax = plt.gca()
    xmin, xmax = ax.get_xbound()

    if(p2[0] == p1[0]):
        xmin = xmax = p1[0]
        ymin, ymax = ax.get_ybound()
    else:
        ymax = p1[1]+(p2[1]-p1[1])/(p2[0]-p1[0])*(xmax-p1[0])
        ymin = p1[1]+(p2[1]-p1[1])/(p2[0]-p1[0])*(xmin-p1[0])

    l = mlines.Line2D([xmin,xmax], [ymin,ymax])
    ax.add_line(l)
    return l

x = np.linspace(0,10)
y = x**2

p1 = [1,20]
p2 = [7,70]

plt.plot(x, y)
newline(p1,p2)
plt.show()
